# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# A1. Matplotlib is a popular Python library used for creating static, animated, and interactive visualizations in a wide range of fields, including data analysis, scientific research, and data presentation.

# %% [markdown]
# Some common plots that can be created using the Pyplot module of Matplotlib include:

# %% [markdown]
# -> lineplot

# %% [markdown]
# ->scatter plot

# %% [markdown]
# ->histogram plot

# %% [markdown]
# ->bar chart

# %% [markdown]
# -> pie-chart

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("this is my x-axis")
plt.ylabel("this is my y-axis")
plt.title("this is my title")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title('Line Plot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A4. A bar plot, also known as a bar chart, is a data visualization technique that uses rectangular bars to represent and compare the values of different categories or data points. It is typically used to display categorical data and is especially useful for:
#
# Comparing Values: Bar plots make it easy to compare the magnitudes of different categories or data points.
#
# Showing Distribution: They can illustrate the distribution or frequency of data within each category.
#
# Visualizing Rankings: Bar plots can display rankings, such as the top N items in a list.
#
# Tracking Changes Over Time: In some cases, bar plots can be used to show changes in values across different time periods or categories.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.tight_layout()
plt.show()

# %%
plt.barh(company,profit)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A5. A box plot, also known as a box-and-whisker plot, is a graphical representation of a dataset's summary statistics and distribution. It is used to display the central tendency, spread, and presence of outliers in numerical data. Box plots are especially useful for comparing distributions, identifying outliers, and gaining insights into data variability.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title('Box Plot of Box 1 and Box 2')
plt.ylabel('Values')
plt.show()
